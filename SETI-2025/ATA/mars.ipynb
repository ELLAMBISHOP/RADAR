# %%
import numpy as np 
import blimpy as bl 
from blimpy import Waterfall
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ff = Waterfall('/datax/scratch/ellambishop/fil_60885_79321_33211791_mars_0001-beam0000.h5')

# %%
ff.plot_spectrum(f_start=8399.5, f_stop=8400.5)
plt.show()
# Out:
# extracting integration 0...

# %%
# !seticore --input /datax/scratch/ellambishop/fil_60885_79321_33211791_mars_0001-beam0000.h5 --output hits.dat
# Out:
# welcome to seticore, version 1.0.6
# running in dedoppler mode.
# loading input from /datax/scratch/ellambishop/fil_60885_79321_33211791_mars_0001-beam0000.h5
# dedoppler parameters: max_drift=10.00 min_drift=0.0000 snr=25.00
# writing output to hits.dat
# hit: coarse channel = 8, index = 47186, snr = 57.46249, drift rate = 0.00000 (0 bins)
# hit: coarse channel = 96, index = 131072, snr = 209611.18750, drift rate = 0.00000 (0 bins)
# hit: coarse channel = 136, index = 61537, snr = 138.54393, drift rate = -3.12455 (-852 bins)
# hit: coarse channel = 136, index = 198995, snr = 314.26331, drift rate = -3.34459 (-912 bins)
# hit: coarse channel = 137, index = 74261, snr = 154.38683, drift rate = -3.12455 (-852 bins)
# hit: coarse channel = 157, index = 260331, snr = 628.64386, drift rate = 2.79816 (763 bins)
# hit: coarse channel = 158, index = 260332, snr = 567.42737, drift rate = 2.84217 (775 bins)
# dedoppler elapsed time: 180s

# %%
# !seticore --input

# %%
ff.plot_waterfall(f_start= 8431.246, f_stop= 8431.248)
plt.show()

# %%
ff.plot_waterfall(f_start= 8420.391, f_stop=  8420.392)
plt.show()
